# %% [markdown]
#    _██_
#   ‹(●̮•)›
#     (█)
#     / |
#
# ## Data Science Live exercises ##
#
# R Script based on Data Science Live exercises, by **Rob Campanell (org.)**.
# **Episode 1: Filter**
# Avaliable from: http://datasciencelive.com/post/2020/05/01/episode1filter/

# %% [markdown]
# ### Librarys used

# %%
library(dplyr)
library(readr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# ### Reading Data From URL

# %%
seattle_art <- read_csv("https://data.seattle.gov/api/views/j7sn-tdzk/rows.csv?accessType=DOWNLOAD")
# Out:
# Parsed with column specification:
# cols(
#   sac_id = col_character(),
#   project = col_character(),
#   artist_first_name = col_character(),
#   artist_last_name = col_character(),
#   title = col_character(),
#   description = col_character(),
#   classification = col_character(),
#   media = col_character(),
#   measurements = col_character(),
#   date = col_character(),
#   location = col_character(),
#   address = col_character(),
#   latitude = col_double(),
#   longitude = col_double(),
#   Geolocation = col_character()
# )

# %% [markdown]
# ### Filtering the Instalation: Classification

# %%
installation <- seattle_art %>% # reading this %>% as 'and then'.
                filter(classification == 'Installation') %>%
                distinct() # to eliminate the duplicates.

# %%
installation
# Out:
#    sac_id    project
# 1  LIB06.010 LIBRARIES FOR ALL - NORTHGATE  BRANCH
# 2  LIB05.052 CENTRAL LIBRARY - LIBRARY UNBOUND
# 3  LIB05.009 LIBRARIES FOR ALL - WALLINGFORD BRANCH
# 4  LIB05.007 LIBRARIES FOR ALL - INTERNATIONAL DISTRICT/CHINATOWN BRANCH
# 5  FFD05.022 SEATTLE CIVIC CENTER-CITY HALL-HILLCLIMB PROJECT
# 6  LIB05.026 LIBRARIES FOR ALL - LAKE CITY  BRANCH
# 7  PR05.047  WEST SEATTLE CULTURAL TRAIL
# 8  LIB05.018 LIBRARIES FOR ALL - CENTRAL LIBRARY
# 9  LIB05.006 LIBRARIES FOR ALL - GREENWOOD BRANCH
# 10 FFD04.097 SEATTLE CIVIC CENTER-CITY HALL- NATIVE AMERICAN PURCHASE
# 11 SPU03.019 CEDAR RIVER WATERSHED
#    artist_first_name artist_last_name
# 1  Dana Lynn         Louis
# 2  George            Legrady
# 3  Richard           Elliott
# 4  Rene              Yung
# 5  Beliz             Brother
# 6  Linda             Haworth
# 7  Donald            Fels
# 8  Ann               Hamilton
# 9  Fernanda          D' Agostino, Fernanda
# 10 Eric              Robertson
# 11 Dan               Corson
#    title
# 1  Circulation
# 2  Making Visible the Invisible
# 3  Five Neons
# 4  Wellspring
# 5  illumine
# 6  Collections  Objects, Experiences, Memories
# 7  Story Viewers
# 8  LEW Floor
# 9  Into the Green Wood
# 10 Evolving Wing and the Gravity of Presence
# 11 Snaking Root Ceiling
#    description
# 1  'A vertical installation of colored glass circles fused onto glass panels.  The glass panels are integrated into the book drop at the plaza entry to the branch.  There are two visual layers that make up this work, the first being abstracting “drawing” in the glass that illustrates the general concept of language and the second a visual calligraphic abstraction of language. Conceptually, the piece refers to the collection, digestion and dissemination of knowledge that occurs daily at the library.'
# 2  'An electronic Installation consisting of animated visualizations on six plasma screens located on a glass wall horizontally behind the librarians' main information desk in the Mixing Chamber, an open public space dedicated to online computer research.  '
# 3  'Five window hung neon pieces of artwork that express the unique activities of the Wallingford Library.  The neon artworks consist of five symbols, each representing a different aspect of the Library.  The five symbols are the glove, a jigsaw puzzle piece,'
# 4  'Wellspring is a collection of teacups donated by the community, each cup an individual well of nourishment, and jointly, a gathering of goodwill and vitality.  '
# 5  'A series of glass dichroic discs, 24" in diameter, are suspended from the ceiling to create illumine, an ever-changing artwork in the glass lantern tower on the northwest corner of City Hall.  Viewed from all four sides, above and below, the discs create a transparent abstraction of shifting color and light.'
# 6  'The artwork is a series of clear glass panels installed into a metal grillwork at the Library and Neighborhood Service Center entrances.  Each glass piece is from one of 21 original images that was first carved in clay.  '
# 7  'The artwork consists of 5 story viewers.   A salmon story, told to the artist by Native American elders, is depicted with story viewers that provide views of the river through the eyes of the salmon in the story.'
# 8  'A tongue-and-groove 7200 square maple floor which appears as a sea of wooden type.  Each length of board is routed with one or more lines of text.  The floor includes 556 lines of text, in reverse, in eleven languages and alphabets, and consists of the first sentences of books found in the ESL/World Languages collection.  The type is set in reverse for two reasons: to reference how books are produced from typeface and to reference how we learn to read, from symbols that are first unknown to us.'
# 9  'Multi-layered tempered laminated glass with silk-screened glass enamels in insulated glass units and installed as an architectural component in the front facade window and panels in the reading room and study room windows. '
# 10 'A mixed media Installation, drawing inspiration from "Paddle to Seattle" an event that brings together many Pacific Northwest tribal groups, the artwork also makes connections to Seattle's local aerospace industry. '
# 11 'Four tree roots, harvested in the area, are suspended in the pitched-roof entry to the Education Center.  Loose material harvested with the roots, such as rocks remain, secured to the roots.  Three tree remnants are intertwined with five to seven root-like coils and lengths of blue krypton and green argon ligth tubes representing the flow of water and energy and referencing the operations of the watershed system.'
#    classification
# 1  Installation
# 2  Installation
# 3  Installation
# 4  Installation
# 5  Installation
# 6  Installation
# 7  Installation
# 8  Installation
# 9  Installation
# 10 Installation
# 11 Installation
#    media
# 1  Kiln formed and sandblasted, laminated glass
# 2  Digital data on server, 3 computers, 6 LCD screens
# 3  Neon (window mounted)
# 4  Teacups, MDF, epoxy, paint, plywood, sandblasted glass, cast urethane, LED lighting.
# 5  Dichroic coated glass, stainless steel cable and hardware, metal halide lights
# 6  Glass - Bull's-eye Tekta 6mm fused into plaster molds cast from original clay carvings
# 7  Fabricated and welded steel coated with urethane paint, stainless steel etched story panels, bronze and cast iron appliques
# 8  Tongue-and-groove maple floor
# 9  Tempered laminated glass with silk-screened glass enamels in insulated glass units
# 10 Aluminum, yellow cedar wood, copper, flammet stone
# 11 Neon and Krypton gas tubes, preserved old growth tree roots
#    measurements
# 1  13'h x 9'w x 3/4"d
# 2  N.A.
# 3  Five pieces, each 19" x 19"
# 4  Various - 60" x 94" x 5", 9" x 9 7/8" x 4", 20 3/8" x 65 15/16" x 1/4"
# 5  20'8" h x 11'w x 8'10"d
# 6  70 pieces:  37 pieces at 15"h x 15"w, 20 pieces at 23" & 15"w, 13 pieces at 31"h x 15"w.  All pieces are 1"d.  Series of clear glass panels.
# 7  Approximately 65"h x 34"w x 5"d
# 8  7,200 sq ft
# 9  13 panels - various sizes from 37" x 34" to 64 1/2" x 61"
# 10 72' x 11.5'
# 11 Approx. 6' diameter by 6' deep
#    date
# 1  5/1/06
# 2  9/1/05
# 3  6/1/04
# 4  2005
# 5  2005
# 6  2005
# 7  2004
# 8  2004
# 9  2004
# 10 2003
# 11 2002
#    location
# 1  Northgate Branch Library, Plaza entry
# 2  Central Library
# 3  Wallingford Branch Library, interior windows on north side of building.
# 4  International District/Chinatown Branch Library
# 5  Seattle City Hall - Hillclimb Stairwell
# 6  Lake City Branch Library.  Downstairs entrance to Lake City Library and entrance to Lake City Neighborhood Service Center
# 7  West Seattle Cultural Trail - Terminal 107
# 8  Central Library
# 9  Greenwood Branch Library, Meeting room window/study room window
# 10 Seattle City Hall - Fifth Ave Lobby
# 11 Seattle Public Utilities,  Cedar Falls
#    address                                        latitude longitude
# 1  10548 5th Ave NE                               47.70603 -122.3227
# 2  1000 4th Ave                                   47.60650 -122.3331
# 3  1501 N 45th St                                 47.66132 -122.3388
# 4  713 8th Ave S                                  47.59615 -122.3224
# 5  600 4th Ave                                    47.60387 -122.3306
# 6  12501 28th Ave NE                              47.71955 -122.2979
# 7  NA                                             47.55870 -122.3508
# 8  1000 4th Ave                                   47.60650 -122.3331
# 9  8016 Greenwood Ave N                           47.68752 -122.3553
# 10 600 4th Ave                                    47.60252 -122.3285
# 11 19901 Cedar Falls Road S.E., North Bend, Wash. 47.42707 -121.7740
#    Geolocation
# 1  10548 5th Ave NE\nSeattle, WA\n(47.706033, -122.322717)
# 2  1000 4th Ave\nSeattle, WA\n(47.6065, -122.333117)
# 3  1501 N 45th St\nSeattle, WA\n(47.661317, -122.338783)
# 4  713 8th Ave S\nSeattle, WA\n(47.59615, -122.322367)
# 5  600 4th Ave\nSeattle, WA\n(47.603867, -122.33055)
# 6  12501 28th Ave NE\nSeattle, WA\n(47.719547, -122.297861)
# 7  Seattle, WA\n(47.5587, -122.350783)
# 8  1000 4th Ave\nSeattle, WA\n(47.6065, -122.333117)
# 9  8016 Greenwood Ave N\nSeattle, WA\n(47.687517, -122.3553)
# 10 600 4th Ave\nSeattle, WA\n(47.602517, -122.328467)
# 11 19901 Cedar Falls Road S.E., North Bend, Wash.\nSeattle, WA\n(47.427067, -121.774033)

# %% [markdown]
# ### Filtering the Environments: Classification

# %%
environments <- seattle_art %>%
                filter(classification == 'Environments') %>%
                distinct()

# %%
environments
# Out:
#    sac_id          project                                 artist_first_name
# 1  PR88.007.01a-g  WESTLAKE PARK                           Robert
# 2  PR97.004        WEST SEATTLE CULTURAL TRAIL             Joe
# 3  PR94.018        DELRIDGE COMMUNITY CENTER               NA
# 4  SC95.043        EAST/WEST PLAZA-SEATTLE CENTER COLISEUM Scuri
# 5  ST04.095        WEST LAKE UNION PATHWAY                 Maggie
# 6  ESD03.016       MAPLE LEAF NEIGHBORHOOD                 Linda
# 7  PR05.048        WEST SEATTLE CULTURAL TRAIL             Donald
# 8  PR97.038.01     DISCOVERY PARK VISITOR CENTER           Bruce
# 9  SPU03.017       CEDAR RIVER WATERSHED                   Dan
# 10 ST01.018.01-.02 BEACON V                                Clark
# 11 ST00.133        BEACON V                                Glenn
# 12 CL00.154        SEATTLE CITY LIGHT NORTH SERVICE CENTER Claudia
# 13 PR97.038.03a-f  DISCOVERY PARK VISITOR CENTER           Bruce
# 14 PR97.038.02a-d  DISCOVERY PARK VISITOR CENTER           Bruce
# 15 PR94.019        GARFIELD COMMUNITY CENTER               Beliz
# 16 PR83.129        KZOK JIMI HENDRIX MEMORIAL              Larry
# 17 ED82.100a-h     SEATTLE URBAN SPACES PROGRAM            Jack
# 18 PR81.013        MERIDIAN PARK                           Charles
# 19 PR84.091        MT. BAKER PARK                          Wendy
#    artist_last_name title
# 1  Maki             Westlake Star Axis/Seven Hills
# 2  Feddersen        Alki / Duwamish Culture Trail
# 3  Wang Po Shu      Geomantic Artwork
# 4  Scuri            Play Ray Plaza
# 5  Smith            Spur Line
# 6  Haworth          Garden of Color and Light
# 7  Fels             Geo-Slice
# 8  Myers            Leaf Legend
# 9  Corson           Rain Drum Courtyard
# 10 Wiegman          Plynth and Pylon from the Project "Vista"
# 11 Herlihy          Hydro Roots from the project "Vista"
# 12 Fitch            Conductive Paths
# 13 Myers            Ripple Sculptures
# 14 Myers            Strata Benches
# 15 Brother          Proverbs and Icons
# 16 Buckingham       Jimi Hendrix Memorial Viewpoint
# 17 Mackie           Dancer's Series: Steps
# 18 Greening         Meridian Archway
# 19 Brawer           Garden Path
#    description
# 1  ''
# 2  'Various brass insets and etched granite pavers containing text and images pertaining to area history, with poetry and statements about people who have lived in West Seattle.'
# 3  'Environmental piece composed of 3 boulders located on a field outside the center.  Two of the boulders were found on site and placed in triangular juxtaposition with a bronze replica of one of the boulders, creating pathways between the boulders. '
# 4  'Radiating diamond pattern of red, gold and black integrally-colored concrete with inset stainless steel screed marking meridians.'
# 5  'The artwork consists of benches, sidewalk inserts, pedestrian handrail dispersed along the pathway.  View decks have been built in a number of stations.'
# 6  '55 styles of opalescent, irid, dichroic and transparent glass on aluminum as fencing treatment.'
# 7  'The artwork is a column cast in iron of a geo-slice "peel" and explores the geological history of the site.  A team of scientists used a specially designed machine to probe the soil 12 feet down, bringing up a record of what lies below the ground.  A large bluestone paver explains the geology of the area as depicted in the cast iron column.'
# 8  'Entrance walkway to Center is scattered with real leaves trowled and bronze leaves inset into the concrete.'
# 9  'a. Djembe b. Conga c. Djembe d. Nagado e. Standing Ngoma f. Standing Ngoma g. Hoop drum h. Hoop drum I. Hoop drum j. Djembe k. Hoop drum l.Standing Ngoma m. Djembe n. Conga o. Djun djun p. Djembe q. Standing Ngoma r. Strap Taiko\n\nThe exterior court encircled by vine maples includes 21 painted drums, representative of different cultures, and a few scattered artifacts from towns that once were located inside the watershed boundaries.'
# 10 'Each stainless steel landmark is incised with waterjet cut calligraphy created by Alex Wu.  By deconstructing the characters from a confucian proverb and repositioning them according to the laws of chance-Artist Statement  Pylon is a vertical slightly larger'
# 11 'Cast concrete and stainless steel tree planters.  The "foundation of the concept is the give and receive relationship between roots and water." G13'
# 12 'Terrazzo pathways reference the flow of energy within the complex weave of electrical cable using images that honor the work and service of Seattle City Light.'
# 13 'Concrete slabs and stepping stones with relief ripple patterns.'
# 14 'Curved benches with a relief decoration suggestive of earth layers.'
# 15 'Inset in stair risers to Garfield's main entrance using 14 quotations selected from over 100 submitted by community members; the quotations are separated by inlaid icons of various images which were created by local teenagers.'
# 16 'A viewpoint consisting of a series of rocks surrounded by a mosaic walkway in a flame design; the largest rock in the center is heated  --  a "hot rock" meant to symbolize Jimi Hendrix's music.'
# 17 'A collection of inlaid bronze footprints and dance instructions.  Each of eight groups depicts different dance steps including rumba, waltz, tango, busstop* and obeedo*, *= artist’s inventions.'
# 18 'ARCHWAY BETWEEN PARK AND STREET, A CIRCULAR WALKWAY CULMINATES   IN AN S-SHAPED RAMP GRADUALLY DESCENDING TO THE ARCH AT STREET  LEVEL. THE WALLS AND ARCHWAY CONSIST OF STONES GLASS AND TILES  SET INTO CONCRETE'
# 19 'Concrete play sculptures and ceramic inserts of leaves and handprints incorporated into pathway.'
#    classification
# 1  Environments
# 2  Environments
# 3  Environments
# 4  Environments
# 5  Environments
# 6  Environments
# 7  Environments
# 8  Environments
# 9  Environments
# 10 Environments
# 11 Environments
# 12 Environments
# 13 Environments
# 14 Environments
# 15 Environments
# 16 Environments
# 17 Environments
# 18 Environments
# 19 Environments
#    media
# 1  Granite; concrete
# 2  Bronze; stone
# 3  Bronze, stone
# 4  Colored concrete; 1/2 stainless steel screed
# 5  Galvanized steel, salvaged douglas fir, stainless steel, bronze and concrete
# 6  Handmade glass mosaic on aluminum
# 7  Cast iron, steel, aluminum, etched bluestone, concrete
# 8  Concrete, bronze
# 9  Rain drums, resin impregnated paper, plastic, galvanized steel bases, copper tube, dripping mechanism and computer
# 10 Stainless steel
# 11 Concrete and stainless steel
# 12 Terrazzo, stained concrete and stainless steel inserts
# 13 Cast concrete, color pigment
# 14 Cast concrete, color pigment, aggregate
# 15 Cement; aluminum; stone; metal
# 16 Carved rocks; tile
# 17 Bronze, concrete
# 18 Stone, concrete, glass
# 19 Ceramic; concrete
#    measurements
# 1  30'x2'6x18"
# 2  NA
# 3  6'x3'x4'
# 4  APPROX 40,000 SQ FT
# 5  variable, in approximately 10 locations along 1.6 miles of West Lake Union
# 6  30 @ 130" x 8" x 5.5"
# 7  12'h x 6'w x 5'd
# 8  4300 SQ FT
# 9  18 drums,  Varies, drums 14"to 30"diameter see file
# 10 .01 Plynth:  42" x 132" x 18"           .02 Pylon: 84" x 24" x 24"
# 11 24 x 90 x 6"
# 12 NA
# 13 VARIED
# 14 VARIED
# 15 26x588"
# 16 NA
# 17 NA
# 18 9'4"x 65'x 68'
# 19 NA
#    date     location
# 1  1988     Westlake Plaza
# 2  1996-97  Alki Beach
# 3  1993-94  Delridge Community Center
# 4  10/23/95 Seattle Center - Key Arena West Plaza
# 5  2004     West Lake Union (1.6 mi. along west shore)
# 6  2002     Maple Leaf Park fence,
# 7  2004     West Seattle Cultural Trail - Terminal 107
# 8  1997     Discovery Park Visitor Center, entrance walkway+O92
# 9  2003     Seattle Public Utilities, Cedar Falls
# 10 2000     Beacon Avenue and Spokane Street
# 11 2000     Beacon Avenue and Spokane Street
# 12 2000     Seattle City Light - North Service Center
# 13 1997     Discovery Park Visitor Center
# 14 1997     Discovery Park Visitor Center
# 15 1994     Garfield Community Center
# 16 1983     Woodland Park Zoo African Savanna - SW Corner
# 17 1982     Broadway
# 18 1981     Meridian Playground
# 19 NA       Mount Baker Park
#    address                                        latitude longitude
# 1  401 Pine St                                    47.61117 -122.3373
# 2  Bonair Dr SW & Alki Ave SW                     47.58215 -122.4035
# 3  4501 Delridge Wy SW                            47.56357 -122.3645
# 4  400 1st Ave N                                  47.62243 -122.3552
# 5  NA                                             47.63230 -122.3405
# 6  Roosevelt Way NE between NE 83rd and NE 84th.  47.68913 -122.3175
# 7  NA                                             47.55907 -122.3507
# 8  3801 W Government Way                          47.65768 -122.4061
# 9  19901 Cedar Falls Road S.E., North Bend, Wash. 47.42715 -121.7742
# 10 NA                                             47.57073 -122.3080
# 11 NA                                             47.57152 -122.3083
# 12 1900 N 97th St                                 47.69983 -122.3417
# 13 3801 W Government Way                          47.65745 -122.4062
# 14 3801 W Government Way                          47.65747 -122.4065
# 15 2323 E Cherry St                               47.60790 -122.3023
# 16 5500 Phinney Ave N                             47.66703 -122.3493
# 17 E. Pine St to E Roy St.                        47.62297 -122.3208
# 18 4649 Sunnyside Ave N                           47.66490 -122.3337
# 19 2301 Lake Wash Blvd S                          47.58172 -122.2882
#    Geolocation
# 1  401 Pine St\nSeattle, WA\n(47.611167, -122.3373)
# 2  Bonair Dr SW & Alki Ave SW\nSeattle, WA\n(47.58215, -122.403517)
# 3  4501 Delridge Wy SW\nSeattle, WA\n(47.563567, -122.3645)
# 4  400 1st Ave N\nSeattle, WA\n(47.622433, -122.355183)
# 5  Seattle, WA\n(47.6323, -122.340533)
# 6  Roosevelt Way NE between NE 83rd and NE 84th.\nSeattle, WA\n(47.689133, -122.317467)
# 7  Seattle, WA\n(47.559067, -122.350667)
# 8  3801 W Government Way\nSeattle, WA\n(47.657683, -122.406117)
# 9  19901 Cedar Falls Road S.E., North Bend, Wash.\nSeattle, WA\n(47.42715, -121.774217)
# 10 Seattle, WA\n(47.570733, -122.307967)
# 11 Seattle, WA\n(47.571517, -122.308267)
# 12 1900 N 97th St\nSeattle, WA\n(47.699833, -122.34165)
# 13 3801 W Government Way\nSeattle, WA\n(47.65745, -122.406217)
# 14 3801 W Government Way\nSeattle, WA\n(47.657467, -122.40645)
# 15 2323 E Cherry St\nSeattle, WA\n(47.6079, -122.302267)
# 16 5500 Phinney Ave N\nSeattle, WA\n(47.667033, -122.349267)
# 17 E. Pine St to E Roy St.\nSeattle, WA\n(47.622967, -122.320833)
# 18 4649 Sunnyside Ave N\nSeattle, WA\n(47.6649, -122.333683)
# 19 2301 Lake Wash Blvd S\nSeattle, WA\n(47.581717, -122.288167)
